# %% [markdown]
# <a href="https://colab.research.google.com/github/darppan/soc2024/blob/master/latticeplot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
import numpy as np
import matplotlib.pyplot as plt

# Replace 'matrix.txt' with the path to your text file if it is in a different location
matrix = np.loadtxt('lattice100.txt')

plt.imshow(matrix, cmap='bwr', interpolation='nearest')
plt.colorbar(label='Value')
plt.title('2D Array Color Map')
plt.show()
